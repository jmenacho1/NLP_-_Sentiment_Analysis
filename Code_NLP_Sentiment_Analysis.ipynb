# %%
# Initial imports
import os
from pathlib import Path
import pandas as pd
from newsapi import NewsApiClient
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
key = os.getenv("NEWS_API_KEY")   # garence stuff

# %%
# Verify variable type

type(key)
# Out:
# str

# %%
# Verify Key connectivity

(key)
# Out:
# 'c1663debb8fa46dba0048fd4c8d88a49'

# %%
newsapi = NewsApiClient(api_key=key)
# newsapi = NewsApiClient(api_key=NEWS_API_KEY)
# newsapi = NewsApiClient(NEWS_API_KEY=api_key)

# %%
# q=(crypto AND bitcoin) NOT ethereum

# %%
refinery_headlines = newsapi.get_everything(             # this works
    q="storm" and "refinery outage" and "gulf coast",
    from_param='2022-04-10',
    to='2022-04-18',
    language="en",
)

print(f"Total articles about refinery headlines: {refinery_headlines['totalResults']}")


refinery_headlines["articles"]
# Out:
# Total articles about refinery headlines: 293
# [{'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Bankrupt nursing home operator faces attacks over legal shields - Reuters',
#   'description': 'The federal government and families of patients are urging a judge to reject a bankrupt Florida nursing home operator\'s proposed liquidation <a href="https://tmsnrt.rs/36f5wer" target="_blank">plan</a> over its handling of lawsuits blaming the company for pat…',
#   'url': 'https://www.reuters.com/legal/transactional/bankrupt-nursing-home-operator-faces-attacks-over-legal-shields-2022-04-18/',
#   'urlToImage': 'https://www.reuters.com/resizer/1jksaau8RqQ56YH0P5u_AHbs3Kw=/728x381/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/JLSUQTTCCZJAVMKHA5QWSKM4BE.jpg',
#   'publishedAt': '2022-04-18T10:11:00Z',
#   'content': 'The company and law firm names shown above are generated automatically based on the text of the article. We are improving this feature as we continue to test and develop in beta. We welcome feedback,… [+3536 chars]'},
#  {'source': {'id': None, 'name': 'Gulf News'},
#   'author': 'Agencies',
#   'title': 'Confirmed: First interstellar meteor to hit Earth - Gulf News',
#   'description': '<ol><li>Confirmed: First interstellar meteor to hit Earth\xa0\xa0Gulf News\r\n</li><li>Interstellar meteor confirmed to have collided with Earth in 2014, researchers say\xa0\xa0CTV News\r\n</li><li>Scientists Are Skeptical of Space Command’s ‘Interstellar’ Meteor Claims\xa0\xa0Giz…',
#   'url': 'https://gulfnews.com/world/confirmed-first-interstellar-meteor-to-hit-earth-1.1650012583027',
#   'urlToImage': 'https://imagevars.gulfnews.com/2022/04/15/CNEOS-2014-01-08-meteor_1802c7aacc0_medium.jpg',
#   'publishedAt': '2022-04-15T08:07:17Z',
#   'content': 'Top secret documents from the US Space Command have finally revealed details of a mysterious object that blazed over Papua New Guinea eight years ago.On January 8, 2014, the meteor known as CNEOS 201… [+4918 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Vegas, Macau...Dubai? Global casinos raise bets on gambling in the Gulf - Reuters',
#   'description': "It's been the subject of quiet speculation among diplomats and executives for years, but now global casino bosses are setting their sights on a once improbable prize: gambling in the United Arab Emirates",
#   'url': 'https://www.reuters.com/world/middle-east/vegas-macaudubai-global-casinos-raise-bets-gambling-gulf-2022-04-13/',
#   'urlToImage': 'https://www.reuters.com/resizer/WBn-ZkGFmtILwlEMHzGWnsZzc0Y=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/XBYATJEIEBOBREQTMJQ4XPMAVY.jpg',
#   'publishedAt': '2022-04-13T05:11:00Z',
#   'content': "DUBAI/HONG KONG, April 13 (Reuters) - It's been the subject of quiet speculation among diplomats and executives for years, but now global casino bosses are setting their sights on a once improbable p… [+6332 chars]"},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Cheniere Energy exec says surging U.S. natgas prices will spur production - Reuters',
#   'description': 'Top U.S. liquefied natural gas producer Cheniere Energy <a href="https://www.reuters.com/companies/LNG.A" target="_blank">(LNG.A)</a> on Thursday said surging U.S. natural gas prices reflect past underinvestment followed by "a demand shock" as Europe seeks to…',
#   'url': 'https://www.reuters.com/business/energy/cheniere-energy-exec-says-surging-us-natgas-prices-will-spur-production-2022-04-14/',
#   'urlToImage': 'https://www.reuters.com/resizer/D3O7ylOgTE-xTBXIrEXOqJiQbpE=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/DHIY4VUUYZOCVBAIYIEXQMLZJU.jpg',
#   'publishedAt': '2022-04-14T22:14:00Z',
#   'content': 'CAMERON, Louisiana, April 14 (Reuters) - Top U.S. liquefied natural gas producer Cheniere Energy (LNG.A) on Thursday said surging U.S. natural gas prices reflect past underinvestment followed by "a d… [+1965 chars]'},
#  {'source': {'id': None, 'name': 'Deadspin'},
#   'author': 'Grace McDermott',
#   'title': 'A WNBA draft unlike any other',
#   'description': 'The first HBCU player selected in two decades, first round picks from Northwestern and Florida Gulf Coast, UConn and South Carolina waiting until the second round to hear names from their rosters called — yesterday’s WNBA draft showed us just how shaken up th…',
#   'url': 'https://deadspin.com/a-wnba-draft-unlike-any-other-1848784715',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/ab489d36559e405eb9d06ffd31c40fb0.jpg',
#   'publishedAt': '2022-04-12T20:10:00Z',
#   'content': 'The first HBCU player selected in two decades, first round picks from Northwestern and Florida Gulf Coast, UConn and South Carolina waiting until the second round to hear names from their rosters cal… [+3832 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'Analysis: U.S. strategic oil sale speeds fuel-price fix, but at what cost? - Reuters',
#   'description': 'The Biden administration is selling a record amount of emergency oil from national reserves to tame soaring U.S. fuel prices as quickly as possible, but the plan could backfire down the road if the stockpile is not replenished quickly.',
#   'url': 'https://www.reuters.com/business/energy/us-strategic-oil-sale-speeds-fuel-price-fix-what-cost-2022-04-11/',
#   'urlToImage': 'https://www.reuters.com/resizer/f6SewIlh2sQ7MaOlAAunJhMJekY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/L777SFP3SBMIFJUJ5LBTXQEKWU.jpg',
#   'publishedAt': '2022-04-11T05:06:00Z',
#   'content': 'April 11 (Reuters) - The Biden administration is selling a record amount of emergency oil from national reserves to tame soaring U.S. fuel prices as quickly as possible, but the plan could backfire d… [+5022 chars]'},
#  {'source': {'id': 'al-jazeera-english', 'name': 'Al Jazeera English'},
#   'author': 'Al Jazeera',
#   'title': 'Ship carrying 750 tonnes of diesel sinks off Tunisia’s coast',
#   'description': 'Vessel, headed from Egypt to Malta, had requested entry to Tunisian waters on Friday evening due to bad weather.',
#   'url': 'https://www.aljazeera.com/news/2022/4/16/merchant-fuel-ship-sinks-off-tunisia-crew-rescued-sources',
#   'urlToImage': 'https://www.aljazeera.com/wp-content/uploads/2020/01/ae43acbd384b480fbac48568eb38e4e3_18.jpeg?fit=1000%2C561',
#   'publishedAt': '2022-04-16T10:29:17Z',
#   'content': 'A ship carrying 750 tonnes of diesel from Egypt to Malta has sunk in the Gulf of Gabes off Tunisias southeast coast.\r\nThe ship sank this morning in Tunisian territorial waters. For the moment, there … [+1080 chars]'},
#  {'source': {'id': None, 'name': '9to5Mac'},
#   'author': 'Filipe Espósito',
#   'title': 'Apple Maps adds cycling directions for users in Chicago, Detroid, and other US cities',
#   'description': 'One of the features introduced to Apple Maps with iOS 14 is cycling directions to help cyclists find the best routes with bike lanes. Now the company has expanded the cycling directions in its Maps app to users located in Chicago, Detroid, and other Midwester…',
#   'url': 'https://9to5mac.com/2022/04/18/apple-maps-adds-cycling-directions-for-users-in-chicago-detroid-and-other-us-cities/',
#   'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2022/04/Apple-Maps-cycling-directions.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#   'publishedAt': '2022-04-18T23:02:14Z',
#   'content': 'One of the features introduced to Apple Maps with iOS 14 is cycling directions to help cyclists find the best routes with bike lanes. Now the company has expanded the cycling directions in its Maps a… [+1488 chars]'},
#  {'source': {'id': None, 'name': 'Newsherald.com'},
#   'author': 'Samantha Neely, The News Herald',
#   'title': "'We're gonna survive this': Bay County officials hold emergency meeting on paper mill closure",
#   'description': 'The Bay County Commission held an emergency meeting to discuss solutions for helping displaced workers find jobs when the WestRock paper mill closes.',
#   'url': 'https://www.newsherald.com/story/news/local/2022/04/12/panama-city-paper-mill-closing-bay-county-officials-discuss-solutions/7274088001/',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/eCCLP5LIy.wZLl.yeZJudQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDM-/https://s.yimg.com/uu/api/res/1.2/yOWPLLxqz4AXSVrthjU3jw--~B/aD0zNTgwO3c9NTM0NzthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/panama-city-news-herald/d4ed315277888fba15b05dbd5185b5af',
#   'publishedAt': '2022-04-12T11:01:21Z',
#   'content': "The 92-year-old WestRock Paper Mill in Panama City will cease operations after June 6, leaving 450 employees without a job.\r\nPANAMA CITY After receiving word of Bay County's iconic paper mill closing… [+7438 chars]"},
#  {'source': {'id': 'al-jazeera-english', 'name': 'Al Jazeera English'},
#   'author': 'Al Jazeera',
#   'title': 'No leaks detected so far in fuel-laden ship that sunk off Tunisia',
#   'description': "Divers have inspected the hull of the tanker that sank off Tunisia's coast with 750 tonnes of diesel.",
#   'url': 'https://www.aljazeera.com/news/2022/4/17/divers-inspect-fuel-laden-ship-sunk-off-tunisia',
#   'urlToImage': 'https://www.aljazeera.com/wp-content/uploads/2022/04/2022-04-17T090802Z_1288995357_RC2XOT9OUZNY_RTRMADP_3_TUNISIA-SHIP.jpg?resize=1200%2C630',
#   'publishedAt': '2022-04-17T12:18:38Z',
#   'content': 'Divers have inspected the hull of a tanker loaded with 750 tonnes of fuel that sank off southeastern Tunisia, with no leak detected so far, officials said.\r\nThe crew of the Xelo had made a distress c… [+1638 chars]'},
#  {'source': {'id': 'bleacher-report', 'name': 'Bleacher Report'},
#   'author': 'Joseph Zucker',
#   'title': 'WNBA Draft 2022: Start Time, Schedule, Round 1 Order and Mock Predictions',
#   'description': 'After spending a few years in the wilderness, the Atlanta Dream put themselves on a path back to relevancy ahead of the 2022 WNBA draft.   The Dream  acquired  the No...',
#   'url': 'https://bleacherreport.com/articles/2955120-wnba-draft-2022-start-time-schedule-round-1-order-and-mock-predictions',
#   'urlToImage': 'https://img.bleacherreport.net/img/slides/photos/004/512/508/27b6bcbaa16ee20a53e92a9cb804861e_crop_exact.jpg?w=1200&h=1200&q=75',
#   'publishedAt': '2022-04-10T14:00:00Z',
#   'content': 'Andy Lyons/Getty Images\r\n1. Atlanta Dream: Rhyne Howard, G, Kentucky\r\n2. Indiana Fever: NaLyssa Smith, F, Baylor\r\n3. Washington Mystics:\xa0Shakira Austin, C, Ole Miss\r\n4. Indiana Fever (via Sparks): Ki… [+499 chars]'},
#  {'source': {'id': 'bloomberg', 'name': 'Bloomberg'},
#   'author': 'Paul Takahashi',
#   'title': 'Murphy Oil Strikes First Oil From New Gulf of Mexico Project',
#   'description': '',
#   'url': 'https://www.bloomberg.com/news/articles/2022-04-12/murphy-oil-strikes-first-oil-from-new-gulf-of-mexico-project',
#   'urlToImage': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/iMNJydHRN0tc/v1/1200x800.jpg',
#   'publishedAt': '2022-04-12T12:31:58Z',
#   'content': 'Murphy Oil Corp. has begun producing oil from a new deepwater Gulf of Mexico project, months ahead of schedule.\r\nThe offshore and shale oil producer on Tuesday said its Kings Quay floating production… [+1441 chars]'},
#  {'source': {'id': None, 'name': 'CNA'},
#   'author': None,
#   'title': 'Vegas, Macao ... Dubai? Global casinos raise bets on gambling in Gulf...',
#   'description': "DUBAI: It's been the subject of quiet speculation among diplomats and executives for years, but now global casino bosses are setting their sights on a once improbable prize -\xa0gambling in the United Arab Emirates.\r\n\r\nRas Al Khaimah (RAK), one of the smaller an…",
#   'url': 'https://www.channelnewsasia.com/business/united-arab-emirates-uae-gambling-global-casinos-resorts-2623406',
#   'urlToImage': 'https://onecms-res.cloudinary.com/image/upload/s--OYXSt0GG--/fl_relative,g_south_east,l_one-cms:core:watermark:reuters,w_0.1/f_auto,q_auto/c_fill,g_auto,h_676,w_1200/v1/one-cms/core/2022-04-13t090004z_4_lynxnpei3c04q_rtroptp_3_emirates-economy-gambling.jpg?itok=T5mx66mI',
#   'publishedAt': '2022-04-13T11:37:40Z',
#   'content': "DUBAI: It's been the subject of quiet speculation among diplomats and executives for years, but now global casino bosses are setting their sights on a once improbable prize -\xa0gambling in the United A… [+2693 chars]"},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'David Bressan, Contributor, \n David Bressan, Contributor\n https://www.forbes.com/sites/davidbressan/',
#   'title': 'Gulf Stream Collapse Will Likely Not Cause Climate Catastrophe',
#   'description': "The idea that the abrupt collapse of the Gulf Stream and associated oceanic currents in the Atlantic Ocean leads to a catastrophic shift in the climate doesn't fit geological data, a new study says.",
#   'url': 'https://www.forbes.com/sites/davidbressan/2022/04/12/gulf-stream-collapse-will-likely-not-cause-climate-catastrophe/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/62557f0ae704e1b5f6bc99cb/0x0.jpg?format=jpg&width=1200',
#   'publishedAt': '2022-04-12T14:10:15Z',
#   'content': 'Visualization showing Gulf Stream Sea Surface Currents and Temperatures.\r\nGreg Shirah/NASA\r\nThe 2004 science-fiction/disaster film "The Day After Tomorrow" is loosely based on the science that the ab… [+4352 chars]'},
#  {'source': {'id': None, 'name': 'Theonion.com'},
#   'author': 'Sirhan Sirhan',
#   'title': 'Bored Kamala Harris Doodles Cartoon Of Refugee Being Thrown Out Of Airplane In Margin Of Notes',
#   'description': 'WASHINGTON—As she absentmindedly sketched in the margin of her notes during a national security meeting Monday, a bored Kamala Harris was seen doodling a cartoon of a refugee who had been thrown out of an airplane, with the word “Noooooo!” appearing in a spee…',
#   'url': 'https://www.theonion.com/bored-kamala-harris-doodles-cartoon-of-refugee-being-th-1848769893',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/7c2a9add032009eb867e7413bfa54aa7.jpg',
#   'publishedAt': '2022-04-11T12:00:00Z',
#   'content': 'WASHINGTONAs she absentmindedly sketched in the margin of her notes during a national security meeting Monday, a bored Kamala Harris was seen doodling a cartoon of a refugee who had been thrown out o… [+882 chars]'},
#  {'source': {'id': 'cbs-news', 'name': 'CBS News'},
#   'author': 'CBS News',
#   'title': '4/13: CBS News Mornings',
#   'description': 'Manhunt continues after at least 10 people shot in Brooklyn subway; Millions in path of storms today from Gulf Coast to Great Lakes',
#   'url': 'https://www.cbsnews.com/video/41322-cbs-news-mornings/',
#   'urlToImage': 'https://cbsnews2.cbsistatic.com/hub/i/r/2022/04/13/9679b0ea-94b6-409a-b1d5-1aaddba6446c/thumbnail/1200x630/9e8f9e418a9bf6ff1237ee2fe0c6a4af/0413-cbsnewsmornings-full-960267-640x360.jpg',
#   'publishedAt': '2022-04-13T15:29:38Z',
#   'content': 'Watch CBS News\r\nCopyright ©2022 CBS Interactive Inc. All rights reserved.\r\nGet browser notifications for breaking news, live events, and exclusive reporting.\r\nNot NowTurn On'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Jared Ranahan, Contributor, \n Jared Ranahan, Contributor\n https://www.forbes.com/sites/jaredranahan/',
#   'title': 'For Earth Day: Five Idyllic Ecotourism Destinations Across The Southern U.S.',
#   'description': 'These Southern getaways offer ample opportunity for birding, outdoor adventure, and basking in the pristine natural beauty of the United States.',
#   'url': 'https://www.forbes.com/sites/jaredranahan/2022/04/12/for-earth-day-five-idyllic-ecotourism-destinations-across-the-southern-us/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/62557c2ddd69caeae6bc99cb/0x0.jpg?format=jpg&crop=1279,720,x0,y132,safe&width=1200',
#   'publishedAt': '2022-04-12T13:52:52Z',
#   'content': 'The U.S. South is home to a wealth of iconic indigenous fauna ranging from the American alligator to ... [+] the Florida panther.\r\nVisit Lake Charles\r\nSpring is in full swing across the Northern Hemi… [+5464 chars]'},
#  {'source': {'id': None, 'name': 'Phys.Org'},
#   'author': 'Science X staff',
#   'title': 'A warm, dry March worsened record drought conditions',
#   'description': 'March 2022 marked the third month in a row where precipitation was below average across the contiguous U.S., which led to an expanding drought and areas of record dryness throughout the West.',
#   'url': 'https://phys.org/news/2022-04-worsened-drought-conditions.html',
#   'urlToImage': 'https://scx2.b-cdn.net/gfx/news/hires/2022/a-warm-dry-march-worse.jpg',
#   'publishedAt': '2022-04-11T15:05:58Z',
#   'content': 'March 2022 marked the third month in a row where precipitation was below average across the contiguous U.S., which led to an expanding drought and areas of record dryness throughout the West.\r\nMarch … [+3639 chars]'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Jim Foerster, Contributor, \n Jim Foerster, Contributor\n https://www.forbes.com/sites/jimfoerster/',
#   'title': 'The 2022 Hurricane Outlook: Another Season Of Increased Storm Activity',
#   'description': 'In what is becoming the norm, another above-average hurricane season is in the forecast for 2022. Conditions appear favorable particularly in the Atlantic, so now is the time for businesses and residents, to prepare for the potential risks.',
#   'url': 'https://www.forbes.com/sites/jimfoerster/2022/04/18/the-2022-hurricane-outlook-another-season-of-increased-storm-activity/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/625d5e6b9adb04b301b4cd9b/0x0.jpg?format=jpg&width=1200',
#   'publishedAt': '2022-04-18T12:55:29Z',
#   'content': 'Hurricane Ida was the most devastating hurricane to make landfall in 2021. Much like 2021, 2022 is ... [+] also shaping up to be an active season and now is the time for businesses and residents, to … [+4202 chars]'},
#  {'source': {'id': None, 'name': 'Phys.Org'},
#   'author': 'Science X staff',
#   'title': 'Microplastics permeate seafood across southern Australia',
#   'description': "Plastic rubbish is everywhere and now broken-down microplastics have been found in variable concentrations in blue mussels and water within the intertidal zone at some of southern Australia's most popular and more remote beaches.",
#   'url': 'https://phys.org/news/2022-04-microplastics-permeate-seafood-southern-australia.html',
#   'urlToImage': 'https://scx2.b-cdn.net/gfx/news/hires/2022/microplastics-permeate-1.jpg',
#   'publishedAt': '2022-04-18T12:47:10Z',
#   'content': "Plastic rubbish is everywhere and now broken-down microplastics have been found in variable concentrations in blue mussels and water within the intertidal zone at some of southern Australia's most po… [+4431 chars]"}]

# %%
# create sentiment score & store it in df:
text_sentiment = []

for article in refinery_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        text_sentiment.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
    except AttributeError:
        pass

# %%
# The sum of pos, neg, neu intensities give 1. 
# Compound ranges from -1 to 1 and is the metric used to draw the overall sentiment.
  # positive if compound >= 0.5
  # neutral if -0.5 < compound < 0.5
  # negative if -0.5 >= compound

sentiment
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# Visualize results in a dataframe

df=pd.DataFrame(text_sentiment)
df
# Out:
#                                                  text                  date  \
# 0   The company and law firm names shown above are...  2022-04-18T10:11:00Z
# 1   Top secret documents from the US Space Command...  2022-04-15T08:07:17Z
# 2   DUBAI/HONG KONG, April 13 (Reuters) - It's bee...  2022-04-13T05:11:00Z
# 3   CAMERON, Louisiana, April 14 (Reuters) - Top U...  2022-04-14T22:14:00Z
# 4   The first HBCU player selected in two decades,...  2022-04-12T20:10:00Z
# 5   April 11 (Reuters) - The Biden administration ...  2022-04-11T05:06:00Z
# 6   A ship carrying 750 tonnes of diesel from Egyp...  2022-04-16T10:29:17Z
# 7   One of the features introduced to Apple Maps w...  2022-04-18T23:02:14Z
# 8   The 92-year-old WestRock Paper Mill in Panama ...  2022-04-12T11:01:21Z
# 9   Divers have inspected the hull of a tanker loa...  2022-04-17T12:18:38Z
# 10  Andy Lyons/Getty Images\r\n1. Atlanta Dream: R...  2022-04-10T14:00:00Z
# 11  Murphy Oil Corp. has begun producing oil from ...  2022-04-12T12:31:58Z
# 12  DUBAI: It's been the subject of quiet speculat...  2022-04-13T11:37:40Z
# 13  Visualization showing Gulf Stream Sea Surface ...  2022-04-12T14:10:15Z
# 14  WASHINGTONAs she absentmindedly sketched in th...  2022-04-11T12:00:00Z
# 15  Watch CBS News\r\nCopyright ©2022 CBS Interact...  2022-04-13T15:29:38Z
# 16  The U.S. South is home to a wealth of iconic i...  2022-04-12T13:52:52Z
# 17  March 2022 marked the third month in a row whe...  2022-04-11T15:05:58Z
# 18  Hurricane Ida was the most devastating hurrica...  2022-04-18T12:55:29Z
# 19  Plastic rubbish is everywhere and now broken-d...  2022-04-18T12:47:10Z
#
#     compound  positive  negative  neutral
# 0     0.7003     0.142     0.000    0.858
# 1     0.2023     0.050     0.000    0.950
# 2     0.0000     0.000     0.000    1.000
# 3     0.7845     0.248     0.000    0.752
# 4     0.0000     0.000     0.000    1.000
# 5    -0.2023     0.000     0.052    0.948
# 6     0.0000     0.000     0.000    1.000
# 7     0.7845     0.161     0.000    0.839
# 8     0.0000     0.000     0.000    1.000
# 9    -0.7906     0.000     0.190    0.810
# 10    0.1027     0.058     0.046    0.896
# 11    0.0000     0.000     0.000    1.000
# 12    0.8462     0.203     0.000    0.797
# 13    0.0000     0.000     0.000    1.000
# 14    0.0772     0.070     0.061    0.870
# 15    0.1280     0.059     0.000    0.941
# 16    0.4939     0.084     0.000    0.916
# 17    0.0000     0.000     0.000    1.000
# 18   -0.1010     0.114     0.100    0.786
# 19    0.0000     0.000     0.000    1.000

# %%
# sort the compound values by descending score

df.sort_values(by='compound', ascending=False).head(5)
# Out:
#                                                  text                  date  \
# 12  DUBAI: It's been the subject of quiet speculat...  2022-04-13T11:37:40Z
# 7   One of the features introduced to Apple Maps w...  2022-04-18T23:02:14Z
# 3   CAMERON, Louisiana, April 14 (Reuters) - Top U...  2022-04-14T22:14:00Z
# 0   The company and law firm names shown above are...  2022-04-18T10:11:00Z
# 16  The U.S. South is home to a wealth of iconic i...  2022-04-12T13:52:52Z
#
#     compound  positive  negative  neutral
# 12    0.8462     0.203       0.0    0.797
# 7     0.7845     0.161       0.0    0.839
# 3     0.7845     0.248       0.0    0.752
# 0     0.7003     0.142       0.0    0.858
# 16    0.4939     0.084       0.0    0.916

# %%
# sort the compound values by asscending score

df.sort_values(by='compound', ascending=True).head(5)
# Out:
#                                                  text                  date  \
# 9   Divers have inspected the hull of a tanker loa...  2022-04-17T12:18:38Z
# 5   April 11 (Reuters) - The Biden administration ...  2022-04-11T05:06:00Z
# 18  Hurricane Ida was the most devastating hurrica...  2022-04-18T12:55:29Z
# 17  March 2022 marked the third month in a row whe...  2022-04-11T15:05:58Z
# 13  Visualization showing Gulf Stream Sea Surface ...  2022-04-12T14:10:15Z
#
#     compound  positive  negative  neutral
# 9    -0.7906     0.000     0.190    0.810
# 5    -0.2023     0.000     0.052    0.948
# 18   -0.1010     0.114     0.100    0.786
# 17    0.0000     0.000     0.000    1.000
# 13    0.0000     0.000     0.000    1.000
